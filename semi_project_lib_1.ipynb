# %%
import pandas as pd 
import re
import numpy as np
import googlemaps
import json
import warnings #경고 제거
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv("전국도서관표준데이터-20201223.csv",header=1,encoding='utf-8') #CP949 , EUC-KR4
df
# Out:
#                  도서관명    시도명 시군구명  도서관유형  \
# 0         중랑구립면목정보도서관  서울특별시  중랑구  공공도서관
# 1           중랑숲어린이도서관  서울특별시  중랑구  공공도서관
# 2            중화어린이도서관  서울특별시  중랑구  공공도서관
# 3             양원숲속도서관  서울특별시  중랑구  공공도서관
# 4             중랑상봉도서관  서울특별시  중랑구  공공도서관
# 5            송파글마루도서관  서울특별시  송파구  공공도서관
# 6            송파어린이도서관  서울특별시  송파구  공공도서관
# 7               거마도서관  서울특별시  송파구  공공도서관
# 8             소나무언덕1호  서울특별시  송파구  공공도서관
# 9             소나무언덕2호  서울특별시  송파구  공공도서관
# 10            소나무언덕3호  서울특별시  송파구  공공도서관
# 11            소나무언덕4호  서울특별시  송파구  공공도서관
# 12         소나무언덕 잠실본동  서울특별시  송파구  공공도서관
# 13            송파어린이영어  서울특별시  송파구  공공도서관
# 14             돌마리도서관  서울특별시  송파구  공공도서관
# 15            송파위례도서관  서울특별시  송파구  공공도서관
# 16            은평구립도서관  서울특별시  은평구  공공도서관
# 17            증산정보도서관  서울특별시  은평구  공공도서관
# 18            응암정보도서관  서울특별시  은평구  공공도서관
# 19          상림마을작은도서관  서울특별시  은평구  공공도서관
# 20          은평뉴타운 도서관  서울특별시  은평구  공공도서관
# 21       링컨타운책벌레작은도서관  부산광역시  강서구  작은도서관
# 22    아인슈타인타운책벌레작은도서관  부산광역시  강서구  작은도서관
# 23      에디슨타운책벌레작은도서관  부산광역시  강서구  작은도서관
# 24           책나무작은도서관  부산광역시  강서구  작은도서관
# 25      명지한신휴플러스작은도서관  부산광역시  강서구  작은도서관
# 26           솔마레작은도서관  부산광역시  강서구  작은도서관
# 27         에일린의뜰작은도서관  부산광역시  강서구  작은도서관
# 28            동행작은도서관  부산광역시  강서구  작은도서관
# 29         지사꿈꾸는작은도서관  부산광역시  강서구  작은도서관
# ...               ...    ...  ...    ...
# 3453           작은숲도서관  대구광역시  달서구  작은도서관
# 3454         옷박골작은도서관  대구광역시  달서구  작은도서관
# 3455     e편한세상월배작은도서관  대구광역시  달서구  작은도서관
# 3456      레이크뷰행복작은도서관  대구광역시  달서구  작은도서관
# 3457        하브루타작은도서관  대구광역시  달서구  작은도서관
# 3458            서한도서관  대구광역시  달서구  작은도서관
# 3459   월배아이파크1차아이빛도서관  대구광역시  달서구  작은도서관
# 3460      꿈꾸는도서관in휴포레  대구광역시  달서구  작은도서관
# 3461         아이솔작은도서관  대구광역시  달서구  작은도서관
# 3462       달서다문화가족도서관  대구광역시  달서구  작은도서관
# 3463          드림작은도서관  대구광역시  달서구  작은도서관
# 3464            숲속도서관  대구광역시  달서구  작은도서관
# 3465    수목원제일풍경채작은도서관  대구광역시  달서구  작은도서관
# 3466      SF 영어하리 도서관  대구광역시  달서구  작은도서관
# 3467            반포도서관  서울특별시  서초구  공공도서관
# 3468            내곡도서관  서울특별시  서초구  공공도서관
# 3469           책마루도서관  울산광역시   남구  작은도서관
# 3470        포천시립중앙도서관    경기도  포천시  공공도서관
# 3471        포천시립소흘도서관    경기도  포천시  공공도서관
# 3472          옥천군민도서관   충청북도  옥천군  공공도서관
# 3473          광진정보도서관  서울특별시  광진구  공공도서관
# 3474            내가도서관  인천광역시  강화군  공공도서관
# 3475            강화도서관  인천광역시  강화군  공공도서관
# 3476         작은도서관 두럭  광주광역시   서구  작은도서관
# 3477         쉼북카페 도서관  광주광역시   서구  작은도서관
# 3478        아이숲어린이도서관  광주광역시   서구  작은도서관
# 3479       성당포스코더샵도서관  대구광역시  달서구  작은도서관
# 3480   상인역e-편한세상 마을문고  대구광역시  달서구  작은도서관
# 3481     월성푸르지오책마루도서관  대구광역시  달서구  작은도서관
# 3482      월성월드메르디앙도서관  대구광역시  달서구  작은도서관
#
#                                                   휴관일 평일운영시작시각 평일운영종료시각  \
# 0     매월 첫째, 셋째 월요일,법정공휴일(일요일제외) 및 근로자의날(5월1일), 임시휴관일    08:00    23:00
# 1            매주월요일, 법정공휴일(일요일제외) 및 근로자의날(5월1일), 임시휴관일    09:00    18:00
# 2                   매주일요일, 법정공휴일 및 근로자의날(5월1일), 임시휴관일    09:00    18:00
# 3            매주월요일, 법정공휴일(일요일제외) 및 근로자의날(5월1일), 임시휴관일    09:00    18:00
# 4            매주월요일, 법정공휴일(일요일제외) 및 근로자의날(5월1일), 임시휴관일    09:00    20:00
# 5                                       매주월요일+국가지정공휴일    09:00    22:00
# 6                                       매주월요일+국가지정공휴일    09:00    18:00
# 7                                 국가지정공휴일+2째월요일+4째월요일    08:00    23:00
# 8                                       매주월요일+국가지정공휴일    09:00    22:00
# 9                                       매주월요일+국가지정공휴일    09:00    22:00
# 10                                      매주월요일+국가지정공휴일    09:00    22:00
# 11                                      매주월요일+국가지정공휴일    09:00    22:00
# 12                                      매주월요일+국가지정공휴일    09:00    18:00
# 13                                      매주월요일+국가지정공휴일    09:00    18:00
# 14                                      매주월요일+국가지정공휴일    09:00    22:00
# 15                                      매주월요일+국가지정공휴일    09:00    22:00
# 16                                          월요일,법정공휴일    09:00    22:00
# 17                                          금요일,법정공휴일    09:00    22:00
# 18                                          금요일,법정공휴일    09:00    22:00
# 19                                          월요일,법정공휴일    09:00    18:00
# 20                                          금요일,법정공휴일    09:00    22:00
# 21                                  화, 목, 토, 일요일, 공휴일    13:00    17:00
# 22                                                공휴일    13:00    17:00
# 23                                      토요일, 일요일, 공휴일    17:00    21:00
# 24                                      토요일, 일요일, 공휴일    09:00    18:00
# 25                                  화, 목, 토, 일요일, 공휴일    10:00    17:00
# 26                                      토요일, 일요일, 공휴일    09:00    18:00
# 27                                      토요일, 일요일, 공휴일    09:00    18:00
# 28                                           월요일, 공휴일    12:00    17:00
# 29                                      토요일, 일요일, 공휴일    13:00    21:00
# ...                                               ...      ...      ...
# 3453                                   매주 일요일 및 법정공휴일    09:30    20:00
# 3454                                   매주 일요일 및 법정공휴일    09:30    18:00
# 3455                               매주 수·토·일요일 및 법정공휴일    14:00    19:00
# 3456                                 매주 토·일요일 및 법정공휴일    10:00    18:00
# 3457                                 매주 토·일요일 및 법정공휴일    10:30    16:00
# 3458                                 매주 토·일요일 및 법정공휴일    13:00    17:30
# 3459                                   매주 일요일 및 법정공휴일    10:00    21:00
# 3460                                 매주 토·일요일 및 법정공휴일    16:30    21:00
# 3461                                   매주 일요일 및 법정공휴일    10:00    12:00
# 3462                                   매주 일요일 및 법정공휴일    09:00    20:00
# 3463                                   매주 일요일 및 법정공휴일    10:00    17:30
# 3464                                 매주 월·일요일 및 법정공휴일    13:00    18:00
# 3465                                   매주 일요일 및 법정공휴일    09:00    18:00
# 3466                                 매주 토·일요일 및 법정공휴일    13:00    20:00
# 3467                                   매주 월요일 및 법정공휴일    09:00    22:00
# 3468                                   매주 월요일 및 법정공휴일    09:00    22:00
# 3469                매주 월요일, 화요일, 수요일, 금요일, 토요일, 법정공휴일    00:00    00:00
# 3470                                 매월마지막주금요일, 법정공휴일    09:00    22:00
# 3471                               매월 마지막주 월요일, 법정공휴일    09:00    22:00
# 3472                                      매주 월요일, 공휴일    07:00    22:00
# 3473                               매월 둘째, 넷째 화요일, 공휴일    09:00    22:00
# 3474                                            매주금요일    09:00    22:00
# 3475                                            매주월요일    08:00    22:00
# 3476                                   매주일요일, 국가지정공휴일    10:00    18:00
# 3477                                   매주화요일, 국가지정공휴일    10:00    18:00
# 3478                                   매주일요일, 국가지정공휴일    10:00    18:00
# 3479                                 매주 토·일요일 및 법정공휴일    16:00    18:00
# 3480                           매주 화·목·금·토·일요일 및 법정공휴일    15:00    17:00
# 3481                                   매주 일요일 및 법정공휴일    13:00    18:00
# 3482                                 매주 토·일요일 및 법정공휴일    16:00    21:00
#
#      토요일운영시작시각 토요일운영종료시각 공휴일운영시작시각  ...              운영기관명        도서관전화번호  \
# 0        08:00     22:00     00:00  ...          중랑구시설관리공단    02-432-4120
# 1        09:00     17:00     00:00  ...          중랑구시설관리공단   02-6235-1150
# 2        10:00     17:00     00:00  ...          중랑구시설관리공단    02-494-1846
# 3        09:00     17:00     00:00  ...          중랑구시설관리공단    02-432-0711
# 4        09:00     17:00     00:00  ...          중랑구시설관리공단            NaN
# 5        09:00     22:00     09:00  ...         서울특별시 송파구청    02-449-8855
# 6        09:00     18:00     09:00  ...         서울특별시 송파구청    02-418-0303
# 7        08:00     23:00     08:00  ...         서울특별시 송파구청    02-449-2332
# 8        09:00     22:00     09:00  ...         서울특별시 송파구청    02-475-0266
# 9        09:00     22:00     09:00  ...         서울특별시 송파구청    02-424-0083
# 10       09:00     22:00     09:00  ...         서울특별시 송파구청    02-443-0130
# 11       09:00     22:00     09:00  ...         서울특별시 송파구청    02-419-5100
# 12       09:00     18:00     09:00  ...         서울특별시 송파구청    02-412-0750
# 13       09:00     18:00     09:00  ...         서울특별시 송파구청    02-415-3567
# 14       09:00     22:00     09:00  ...         서울특별시 송파구청    02-414-7007
# 15       09:00     22:00     09:00  ...         서울특별시 송파구청    02-402-3003
# 16       09:00     18:00     09:00  ...         사회복지법인 인덕원    02-385-1671
# 17       09:00     18:00     09:00  ...         사회복지법인 인덕원    02-307-6030
# 18       09:00     18:00     09:00  ...        대한성결교회 유지재단    02-308-2320
# 19       09:00     18:00     09:00  ...         사회복지법인 인덕원    02-838-7557
# 20       09:00     18:00     09:00  ...         사회복지법인 인덕원   02-6341-6400
# 21       00:00     00:00     00:00  ...       퀸덤1차 링컨타운아파트   051-271-7170
# 22       00:00     00:00     00:00  ...       퀸덤1차 아이슈타인타운   051-271-7781
# 23       00:00     00:00     00:00  ...         퀸덤1차 에디슨타운   051-271-0541
# 24       00:00     00:00     00:00  ...         강서구종합사회복지관   051-972-4591
# 25       00:00     00:00     00:00  ...           명지한신휴플러스   051-271-2750
# 26       00:00     00:00     00:00  ...          엘크루솔마레아파트   051-271-3999
# 27       00:00     00:00     00:00  ...            명지에일린의뜰   051-291-8855
# 28       12:00     17:00     00:00  ...               동행교회   051-204-1191
# 29       00:00     00:00     00:00  ...  지사꿈꾸는 작은도서관 운영위원회   051-941-1184
# ...        ...       ...       ...  ...                ...            ...
# 3453     09:30     20:00     00:00  ...                NaN   053-587-7902
# 3454     09:00     18:00     00:00  ...                NaN   053-525-0141
# 3455     00:00     00:00     00:00  ...                NaN   053-635-0917
# 3456     20:00     22:00     00:00  ...                NaN   053-638-3434
# 3457     00:00     00:00     00:00  ...                NaN  070-8827-1828
# 3458     00:00     00:00     00:00  ...                NaN   053-585-9980
# 3459     09:00     17:00     00:00  ...                NaN   053-643-7917
# 3460     00:00     00:00     00:00  ...                NaN  070-4209-8891
# 3461     10:00     16:00     00:00  ...                NaN   053-639-1333
# 3462     09:00     16:00     00:00  ...          성서종합사회복지관   053-583-1284
# 3463     10:00     17:00     00:00  ...                NaN   053-281-3639
# 3464     13:00     18:00     00:00  ...                NaN   053-643-7673
# 3465     14:00     18:00     00:00  ...                NaN   053-643-0661
# 3466     00:00     00:00     00:00  ...                NaN   053-552-0191
# 3467     09:00     18:00     09:00  ...          (재)서초문화재단    02-520-8700
# 3468     09:00     18:00     09:00  ...          (재)서초문화재단   02-3461-3007
# 3469     00:00     00:00     08:00  ...             울산제일교회   052-276-4010
# 3470     09:00     18:00     09:00  ...            경기도 포천시   031-538-3912
# 3471     09:00     18:00     09:00  ...            경기도 포천시   031-538-3951
# 3472     07:00     22:00     00:00  ...          충청북도 옥천군청   043-730-3611
# 3473     09:00     17:00     00:00  ...          광진구시설관리공단   02-3437-5092
# 3474     09:00     18:00     09:00  ...         인천광역시 강화군청   032-934-1528
# 3475     08:00     22:00     08:00  ...         인천광역시 강화군청   032-932-8264
# 3476     10:00     18:00     10:00  ...                NaN   062-371-3200
# 3477     10:00     18:00     10:00  ...                NaN   062-350-4545
# 3478     10:00     18:00     10:00  ...                NaN   062-652-1279
# 3479     00:00     00:00     00:00  ...                NaN  070-8911-3402
# 3480     00:00     00:00     00:00  ...                NaN   053-634-5577
# 3481     10:00     13:00     00:00  ...                NaN   053-635-0061
# 3482     00:00     00:00     00:00  ...                NaN   053-638-6920
#
#          부지면적     건물면적                                  홈페이지주소         위도  \
# 0     1167.00  1234.00   http://www.jungnanglib.seoul.kr/mmlib  37.587356
# 1     1021.10   977.80  http://www.jungnanglib.seoul.kr/suplib  37.602634
# 2      763.00   133.00  http://www.jungnanglib.seoul.kr/jhklib  37.595004
# 3         NaN   970.78  http://www.jungnanglib.seoul.kr/ywlib/  37.606825
# 4         NaN  1753.41  http://www.jungnanglib.seoul.kr/sblib/  37.593127
# 5     3697.00  3697.00                  http://www.splib.or.kr  37.480833
# 6     1273.00  1273.00                  http://www.splib.or.kr  37.512101
# 7      886.00   886.00                  http://www.splib.or.kr  37.493545
# 8      177.00   177.00                  http://www.splib.or.kr  37.527417
# 9      329.00   329.00                  http://www.splib.or.kr  37.507267
# 10     343.00   343.00                  http://www.splib.or.kr  37.492325
# 11     246.00   246.00                  http://www.splib.or.kr  37.502207
# 12     510.00   510.00                  http://www.splib.or.kr  37.503101
# 13    1430.00   595.00                  http://www.splib.or.kr  37.522393
# 14     265.00   265.00                  http://www.splib.or.kr  37.503565
# 15     914.00   914.00                  http://www.splib.or.kr  37.481167
# 16    8013.00  5060.00                 http://www.eplib.or.kr/  37.618974
# 17    1142.00  2110.00                http://www.jsplib.or.kr/  37.582808
# 18     748.00   999.00                 http://www.ealib.or.kr/  37.585967
# 19        NaN   311.70                 http://www.eplib.or.kr/  37.644216
# 20    1323.00  1997.00                 http://www.enlib.or.kr/  37.637230
# 21     121.00   121.00                                     NaN  35.086392
# 22     129.00   129.00                                     NaN  35.086373
# 23     131.00   131.00                                     NaN  35.088150
# 24      45.00    45.00                                     NaN  35.216761
# 25     332.00   332.00                                     NaN  35.080813
# 26     382.00   382.00                                     NaN  35.081742
# 27      65.00    65.00                                     NaN  35.100450
# 28     927.00   150.00                                     NaN  35.100981
# 29      77.00    77.00                                     NaN  35.150894
# ...       ...      ...                                     ...        ...
# 3453      NaN    60.80                                     NaN  35.858883
# 3454      NaN    41.52                                     NaN  35.860601
# 3455      NaN    56.83                                     NaN  35.827993
# 3456      NaN    70.90                                     NaN  35.807331
# 3457      NaN    95.00                                     NaN  35.839834
# 3458      NaN    84.50                                     NaN  35.858878
# 3459      NaN   195.00                                     NaN  35.815806
# 3460      NaN   119.00                                     NaN  35.824284
# 3461      NaN   247.00                                     NaN  35.819461
# 3462      NaN    50.00                                     NaN  35.852297
# 3463      NaN    48.00                                     NaN  35.844414
# 3464      NaN    47.52                                     NaN  35.796645
# 3465      NaN    95.26                                     NaN  35.798797
# 3466      NaN    54.04                                     NaN  35.856101
# 3467  3593.48  3593.48      http://www.seocholib.or.kr/docwww/  37.502489
# 3468  1528.00  1528.00   http://naegok.seocholib.or.kr/docnae/  37.452002
# 3469      NaN    54.19                                     NaN  35.549058
# 3470  7249.00  4919.00       https://lib.pocheon.go.kr/center/  37.908101
# 3471  4003.10  1985.01            https://lib.pochoen.go.kr/sh  37.829605
# 3472  4456.00  2864.97                     http://lib.oc.go.kr  36.300444
# 3473      NaN  7283.00        http://www.gwangjinlib.seoul.kr/  37.551074
# 3474   179.00   378.00                    http://www.ghlib.net  37.719349
# 3475  1528.00  2190.00                    http://www.ghlib.net  37.748805
# 3476      NaN    50.00                                     NaN  35.160045
# 3477      NaN    62.80                                     NaN  35.121685
# 3478      NaN    66.00                                     NaN  35.127191
# 3479      NaN   121.00                                     NaN  35.843144
# 3480      NaN    46.00                                     NaN  35.819702
# 3481      NaN   191.00                                     NaN  35.829128
# 3482      NaN   121.65                                     NaN  35.826523
#
#               경도     데이터기준일자   제공기관코드      제공기관명
# 0     127.087557  2020-01-31  3060000  서울특별시 중랑구
# 1     127.103926  2020-01-31  3060000  서울특별시 중랑구
# 2     127.074892  2020-01-31  3060000  서울특별시 중랑구
# 3     127.110697  2020-01-31  3060000  서울특별시 중랑구
# 4     127.080932  2020-01-31  3060000  서울특별시 중랑구
# 5     127.130477  2020-02-20  3230000  서울특별시 송파구
# 6     127.082428  2020-02-20  3230000  서울특별시 송파구
# 7     127.146827  2020-02-20  3230000  서울특별시 송파구
# 8     127.118041  2020-02-20  3230000  서울특별시 송파구
# 9     127.094217  2020-02-20  3230000  서울특별시 송파구
# 10    127.156619  2020-02-20  3230000  서울특별시 송파구
# 11    127.116836  2020-02-20  3230000  서울특별시 송파구
# 12    127.078872  2020-02-20  3230000  서울특별시 송파구
# 13    127.102983  2020-02-20  3230000  서울특별시 송파구
# 14    127.103685  2020-02-20  3230000  서울특별시 송파구
# 15    127.143936  2020-02-20  3230000  서울특별시 송파구
# 16    126.928267  2020-01-01  3110000  서울특별시 은평구
# 17    126.907671  2020-01-01  3110000  서울특별시 은평구
# 18    126.919682  2020-01-01  3110000  서울특별시 은평구
# 19    126.928942  2020-01-01  3110000  서울특별시 은평구
# 20    126.933118  2020-01-01  3110000  서울특별시 은평구
# 21    128.896787  2020-03-16  3360000  부산광역시 강서구
# 22    128.899847  2020-03-16  3360000  부산광역시 강서구
# 23    128.897362  2020-03-16  3360000  부산광역시 강서구
# 24    128.959338  2020-03-16  3360000  부산광역시 강서구
# 25    128.901126  2020-03-16  3360000  부산광역시 강서구
# 26    128.896596  2020-03-16  3360000  부산광역시 강서구
# 27    128.920881  2020-03-16  3360000  부산광역시 강서구
# 28    128.924241  2020-03-16  3360000  부산광역시 강서구
# 29    128.838987  2020-03-16  3360000  부산광역시 강서구
# ...          ...         ...      ...        ...
# 3453  128.495124  2020-09-01  3470000  대구광역시 달서구
# 3454  128.529526  2020-09-01  3470000  대구광역시 달서구
# 3455  128.520914  2020-09-01  3470000  대구광역시 달서구
# 3456  128.546034  2020-09-01  3470000  대구광역시 달서구
# 3457  128.531789  2020-09-01  3470000  대구광역시 달서구
# 3458  128.504812  2020-09-01  3470000  대구광역시 달서구
# 3459  128.514720  2020-09-01  3470000  대구광역시 달서구
# 3460  128.521946  2020-09-01  3470000  대구광역시 달서구
# 3461  128.513714  2020-09-01  3470000  대구광역시 달서구
# 3462  128.498825  2020-09-01  3470000  대구광역시 달서구
# 3463  128.533425  2020-09-01  3470000  대구광역시 달서구
# 3464  128.529465  2020-09-01  3470000  대구광역시 달서구
# 3465  128.531482  2020-09-01  3470000  대구광역시 달서구
# 3466  128.524912  2020-09-01  3470000  대구광역시 달서구
# 3467  127.012535  2020-06-30  3210000  서울특별시 서초구
# 3468  127.054443  2020-06-30  3210000  서울특별시 서초구
# 3469  129.317573  2020-06-25  6310000      울산광역시
# 3470  127.205771  2020-06-10  5600000    경기도 포천시
# 3471  127.137558  2020-06-10  5600000    경기도 포천시
# 3472  127.574922  2020-09-09  4430000   충청북도 옥천군
# 3473  127.110614  2020-06-30  3040000  서울특별시 광진구
# 3474  126.389846  2020-09-18  3570000  인천광역시 강화군
# 3475  126.483160  2020-09-18  3570000  인천광역시 강화군
# 3476  126.860108  2020-09-25  3600000   광주광역시 서구
# 3477  126.868742  2020-09-25  3600000   광주광역시 서구
# 3478  126.879005  2020-09-25  3600000   광주광역시 서구
# 3479  128.547309  2020-09-01  3470000  대구광역시 달서구
# 3480  128.535008  2020-09-01  3470000  대구광역시 달서구
# 3481  128.526021  2020-09-01  3470000  대구광역시 달서구
# 3482  128.523133  2020-09-01  3470000  대구광역시 달서구
#
# [3483 rows x 28 columns]

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 1. 데이터 정리

# %%
df.columns
# Out:
# Index(['도서관명', '시도명', '시군구명', '도서관유형', '휴관일', '평일운영시작시각', '평일운영종료시각',
#        '토요일운영시작시각', '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '열람좌석수', '자료수(도서)',
#        '자료수(연속간행물)', '자료수(비도서)', '대출가능권수', '대출가능일수', '소재지도로명주소', '운영기관명',
#        '도서관전화번호', '부지면적', '건물면적', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
#열 이름 출력
df.columns
#필요한 열 리스트
columns = ['도서관명','시도명','시군구명','열람좌석수','자료수(도서)','자료수(연속간행물)','자료수(비도서)','위도','경도','건물면적','도서관유형']
#필요한 열만 분리해 신규 데이터프레임 생성
df_lib = df[columns]

# %%
#열 정리1. 통합
df_lib['자료수'] = df_lib['자료수(도서)'] + df_lib['자료수(연속간행물)'] + df_lib['자료수(비도서)']

# %%
#열 정리2. 필요없는 열 제거
dropList = ["자료수(도서)", "자료수(연속간행물)", "자료수(비도서)"]
df_lib = df_lib.drop(dropList,axis=1)
df_lib.head()
# Out:
#           도서관명    시도명 시군구명  열람좌석수         위도          경도     건물면적  도서관유형  \
# 0  중랑구립면목정보도서관  서울특별시  중랑구    227  37.587356  127.087557  1234.00  공공도서관
# 1    중랑숲어린이도서관  서울특별시  중랑구    303  37.602634  127.103926   977.80  공공도서관
# 2     중화어린이도서관  서울특별시  중랑구     30  37.595004  127.074892   133.00  공공도서관
# 3      양원숲속도서관  서울특별시  중랑구    252  37.606825  127.110697   970.78  공공도서관
# 4      중랑상봉도서관  서울특별시  중랑구    268  37.593127  127.080932  1753.41  공공도서관
#
#       자료수
# 0  112846
# 1   50731
# 2   23799
# 3   29716
# 4   26780

# %%
#열 정리3. 보기 쉽도록 열 순서 변경
columns = ["도서관명", "시도명", "시군구명", "열람좌석수", "자료수", "위도", "경도", "도서관유형", "건물면적"]
df_lib = df_lib[columns]

# %%
#서울 도서관만 남기기
df_lib = df_lib[df_lib["시도명"] == "서울특별시"]
#index 제거
df_lib.reset_index(inplace=True, drop=True)

# %%
df_lib.head()
# Out:
#           도서관명    시도명 시군구명  열람좌석수     자료수         위도          경도  도서관유형  \
# 0  중랑구립면목정보도서관  서울특별시  중랑구    227  112846  37.587356  127.087557  공공도서관
# 1    중랑숲어린이도서관  서울특별시  중랑구    303   50731  37.602634  127.103926  공공도서관
# 2     중화어린이도서관  서울특별시  중랑구     30   23799  37.595004  127.074892  공공도서관
# 3      양원숲속도서관  서울특별시  중랑구    252   29716  37.606825  127.110697  공공도서관
# 4      중랑상봉도서관  서울특별시  중랑구    268   26780  37.593127  127.080932  공공도서관
#
#       건물면적
# 0  1234.00
# 1   977.80
# 2   133.00
# 3   970.78
# 4  1753.41

# %% [markdown]
# #

# %% [markdown]
# 2. 결측치 채우기

# %%
#결측치 처리를 위한 확인
df_lib.isnull().sum()
# Out:
# 도서관명       0
# 시도명        0
# 시군구명       0
# 열람좌석수      0
# 자료수        0
# 위도        36
# 경도        35
# 도서관유형      0
# 건물면적     188
# dtype: int64

# %% [markdown]
# #

# %% [markdown]
# *건물면적 결측치 채우기*
#
# 1. 건물면적 값이 null인 데이터프레임 생성
# 2. 임의로 값을 넣을만한 기준 구하기(서울 도서관의 열람좌석 1개당 건물면적 중위값)
# 3. 기준에 맞춰 임의의 값 채우기
# 4. 아직 비어있는 셀 구글링 통해 채우기
# 5. 기존 데이터프레임에 삽입

# %%
#결측치 채우기 1. 건물면적(1)

null_df = df_lib[(df_lib["건물면적"].isnull()) & (df_lib["도서관유형"] == "작은도서관")] 
notNull_df = df_lib[df_lib["건물면적"].notnull() & (df_lib['도서관유형'] == "작은도서관")]
buildmean = np.median(notNull_df["건물면적"] / notNull_df["열람좌석수"])
df_lib["건물면적"].fillna(round(null_df["열람좌석수"] * buildmean, 2), inplace = True)
buildmean
# null_df : 건물면적의 값이 null이며 유형이 '작은도서관'인 데이터프레임
# notNull_df : 건물면적의 값이 null이 아니며 유형이 '작은도서관'인 데이터프레임
# buildmean : notNull_df안에서 각 도서관마다 건물면적 / 열람좌석수를 계산하여 열람좌석 1개당 평균건물면적 중위값
# 기존 데이터프레임에서 건물면적이 null인 곳마다 열람좌석수 * buildmean을 채워줌.

## 처음 전체 '건물면적'에서 median 값을 구하고 비교했을 때는 차이가 큼
## null_df['도서관유형'].value_counts()로 도서관유형이 '작은도서관'이 다수(작은도서관: 185, 공공도서관: 3)인 것을 확인하고 수정.
# Out:
# 4.714285714285714

# %%
#결측치 채우기 1. 건물면적(2)

df_lib['건물면적'][85] = '324'
df_lib['건물면적'][86] = '1104'
df_lib['건물면적'][235] = '1396.94'

#df_lib[df_lib['건물면적'].isnull()]로 null 셀의 index 확인 #공공도서관은 구글링을 통해 빈 칸 채우기

# %%
df_lib.isnull().sum()
# Out:
# 도서관명      0
# 시도명       0
# 시군구명      0
# 열람좌석수     0
# 자료수       0
# 위도       36
# 경도       35
# 도서관유형     0
# 건물면적      0
# dtype: int64

# %% [markdown]
# #

# %% [markdown]
# *위도, 경도 결측치 채우기*
#
# 1. 위도와 경도가 null인 데이터프레임 생성
# 2. 구글맵 API에 접근
# 3. 도서관 이름 -----(GoogleMap API)-----> 좌표
# 4. 받아온 좌표들을 리스트에 append
# 5. 검색이 되지않는 도서관들은 따로 error_list로 묶어줌
# 6. 좌표 열 새로 만들기 : (유저와 도서관 사이 거리 계산할때 편하게 좌표를 보내기 위해)
# 7. 좌표 열에 받아온 리스트 삽입
# 8. error_list 확인 후 보완
# 9. 필요없어진 위도, 경도 열 삭제

# %%
#결측치 채우기 2. 위도와 경도(1)

loc_null_df = df_lib[(df_lib["위도"].isnull()) | (df_lib["경도"].isnull())]
loc_null_df.set_index("도서관명", inplace=True)
loc_null_df.head()

#위도와 경도가 NaN값인 데이터 프레임만들기
#도서관명 값에 쉽게 접근하기 위해 index를 "도서관명"으로 설정
#loc_null_df.set_index("도서관명", inplace=True)
# Out:
#                             시도명 시군구명  열람좌석수    자료수  위도  경도  도서관유형     건물면적
# 도서관명
# 사랑꿈터 작은 도서관               서울특별시  은평구     20   4000 NaN NaN  작은도서관    94.29
# 용산 꿈나무도서관                 서울특별시  용산구    150  36597 NaN NaN  공공도서관  1104.00
# 상림6 작은도서관                 서울특별시  은평구     20   8701 NaN NaN  작은도서관    94.29
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)  서울특별시  은평구     20   6024 NaN NaN  작은도서관    94.29
# 은평뉴타운5단지                  서울특별시  은평구     36   4001 NaN NaN  작은도서관   169.71

# %%
#결측치 채우기 2. 위도와 경도(2)

gmaps_key = "############API KEY##########"
gmaps = googlemaps.Client(key = gmaps_key)
#구글맵 API에 할당받은 키로 접속

# %%
#결측치 채우기 2. 위도와 경도(3) 

loc = [] #좌표열에 넣어줄 좌표값
error_list = [] #구글맵내에서 검색이 되지않는 도서관 

for lib_name in loc_null_df.index:
    tmp = gmaps.geocode(lib_name) #주소로 검색해 좌표로 돌려주는 API기능

    if bool(tmp): #검색이 된다면
        tmp_loc = tmp[0].get('geometry')
        lat = tmp_loc['location']['lat']
        lng = tmp_loc['location']['lng']
        if ((lat > 0) & (lng > 0)): #좌표가 -값이면 검색이 잘못된것이므로 error_list 추가
            loc.append(str(lat) + ", " + str(lng))
        else:
            loc.append("0, 0") 
            error_list.append(lib_name)
    else: #주소로 검색이 안 된다면
        loc.append("0, 0") 
        error_list.append(lib_name)
        pass
    
#구글맵 API 활용 코드

# %%
#결측치 채우기 2. 위도와 경도(4)

loc_null_df["좌표"] = loc
loc_null_df.head()
#새로운 '좌표' 열을 만들어 받아온 값 추가
# Out:
#                                   시도명  시군구명  열람좌석수    자료수  위도          경도  \
# 도서관명
# 사랑꿈터 작은 도서관                     서울특별시   은평구     20   4000 NaN         NaN
# 용산 꿈나무도서관                       서울특별시   용산구    150  36597 NaN         NaN
# 상림6 작은도서관                       서울특별시   은평구     20   8701 NaN         NaN
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)        서울특별시   은평구     20   6024 NaN         NaN
# 은평뉴타운5단지                        서울특별시   은평구     36   4001 NaN         NaN
# 모퉁이작은도서관(은평뉴타운 상림마을 14단지 마을문고)  서울특별시   은평구     20   5283 NaN         NaN
# 롯데캐슬문고                          서울특별시   은평구     32   6406 NaN         NaN
# 상림책마루작은도서관                      서울특별시   은평구     35   5700 NaN         NaN
# 우물골작은도서관                        서울특별시   은평구     20   5203 NaN         NaN
# 큰꿈(을 키우는 작은)도서관                 서울특별시   은평구     55   8912 NaN         NaN
# 래미안 푸른숲 도서관                     서울특별시   은평구     28   7000 NaN         NaN
# 두드림 도서관                         서울특별시   은평구     30   6934 NaN         NaN
# 종이책갈피 작은도서관                     서울특별시   은평구     16   4110 NaN         NaN
# 푸른작은도서관                         서울특별시   은평구     25   6126 NaN         NaN
# 솔빛도서관                           서울특별시   은평구     12   1628 NaN         NaN
# 샘터작은도서관                         서울특별시   은평구     16   5282 NaN         NaN
# 책뜰에도서관                          서울특별시   은평구     60   7000 NaN         NaN
# 숲속 향기 작은도서관                     서울특별시   은평구     40   5920 NaN         NaN
# 지혜누리작은도서관                       서울특별시   은평구     20   2556 NaN         NaN
# 산책마을 SH작은도서관                    서울특별시   은평구     58   8599 NaN         NaN
# 나누리작은도서관                        서울특별시   은평구     30   2500 NaN         NaN
# 두근두근작은도서관 (마고정 3단지 도서관)         서울특별시   은평구     30   2400 NaN         NaN
# 물푸레작은도서관                        서울특별시   은평구     35   5000 NaN         NaN
# 새자람작은도서관                        서울특별시   은평구     10   1200 NaN         NaN
# 포수마을 만화도서관                      서울특별시   은평구     30   2051 NaN         NaN
# 백련산힐스 작은도서관                     서울특별시   은평구     22   3000 NaN         NaN
# 영광영재도서관                         서울특별시   은평구     50   7058 NaN         NaN
# 물빛마을작은도서관                       서울특별시   은평구     30   7903 NaN         NaN
# 수색한숲도서관                         서울특별시   은평구     20   4007 NaN         NaN
# 다섯콩작은도서관                        서울특별시   은평구     42  11661 NaN         NaN
# 어린이도서관 동네북                      서울특별시   은평구     50  11899 NaN         NaN
# 북한산 힐스테이트  1차 솔숲문고              서울특별시   은평구     40   7015 NaN         NaN
# 책달샘숲속작은도서관                      서울특별시   금천구     14   2160 NaN  126.907878
# 자양한강도서관                         서울특별시   광진구    370  26139 NaN         NaN
# KB국민은행과 함께하는 나무작은도서관            서울특별시  노원구　     20      0 NaN         NaN
# 메아리작은도서관                        서울특별시  노원구　     14      0 NaN         NaN
#
#                                 도서관유형     건물면적                       좌표
# 도서관명
# 사랑꿈터 작은 도서관                     작은도서관    94.29  37.2669463, 126.9906323
# 용산 꿈나무도서관                       공공도서관  1104.00  37.5385513, 126.9654268
# 상림6 작은도서관                       작은도서관    94.29                     0, 0
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)        작은도서관    94.29  37.6442098, 126.9288736
# 은평뉴타운5단지                        작은도서관   169.71  37.6362597, 126.9356033
# 모퉁이작은도서관(은평뉴타운 상림마을 14단지 마을문고)  작은도서관    94.29  37.6440244, 126.9290277
# 롯데캐슬문고                          작은도서관   150.86  37.5142479, 127.1012726
# 상림책마루작은도서관                      작은도서관   165.00  37.6440244, 126.9290277
# 우물골작은도서관                        작은도서관    94.29                     0, 0
# 큰꿈(을 키우는 작은)도서관                 작은도서관   259.29  37.2797194, 126.8511041
# 래미안 푸른숲 도서관                     작은도서관   132.00  37.2811768, 127.0666219
# 두드림 도서관                         작은도서관   141.43  37.3829909, 127.1220628
# 종이책갈피 작은도서관                     작은도서관    75.43  37.5558027, 126.9421554
# 푸른작은도서관                         작은도서관   117.86                     0, 0
# 솔빛도서관                           작은도서관    56.57  37.7712841, 126.7783032
# 샘터작은도서관                         작은도서관    75.43   37.246472, 127.4914009
# 책뜰에도서관                          작은도서관   282.86                     0, 0
# 숲속 향기 작은도서관                     작은도서관   188.57  37.6356894, 126.9343788
# 지혜누리작은도서관                       작은도서관    94.29  37.3398891, 127.9220033
# 산책마을 SH작은도서관                    작은도서관   273.43   37.2828471, 126.849951
# 나누리작은도서관                        작은도서관   141.43  37.6325169, 126.9250897
# 두근두근작은도서관 (마고정 3단지 도서관)         작은도서관   141.43                     0, 0
# 물푸레작은도서관                        작은도서관    78.00  37.6436577, 126.9297365
# 새자람작은도서관                        작은도서관    47.14   37.6555415, 126.948206
# 포수마을 만화도서관                      작은도서관   141.43  37.5990065, 126.9165033
# 백련산힐스 작은도서관                     작은도서관   103.71  37.5969178, 126.9235298
# 영광영재도서관                         작은도서관   235.71                     0, 0
# 물빛마을작은도서관                       작은도서관   141.43   35.105025, 126.9050141
# 수색한숲도서관                         작은도서관    94.29  37.5865949, 126.9003323
# 다섯콩작은도서관                        작은도서관   198.00                     0, 0
# 어린이도서관 동네북                      작은도서관   235.71    37.576478, 126.967887
# 북한산 힐스테이트  1차 솔숲문고              작은도서관   188.57  37.6126118, 126.9366945
# 책달샘숲속작은도서관                      작은도서관    61.03  37.5005875, 126.7636793
# 자양한강도서관                         공공도서관  1650.00  37.5296093, 127.0779724
# KB국민은행과 함께하는 나무작은도서관            작은도서관    94.29                     0, 0
# 메아리작은도서관                        작은도서관    66.00   37.6530716, 127.057942

# %%
#결측치 채우기 2. 위도와 경도(5)
#error_list => 도서관 이름 확인

loc_null_df["좌표"]["상림6 작은도서관"] = "37.6490888, 126.9280755"
loc_null_df["좌표"]["책뜰에도서관"] = "37.64329638160066, 126.92207614232784"
loc_null_df["좌표"]["두근두근작은도서관 (마고정 3단지 도서관)"] = "37.6324903, 126.918633"
loc_null_df["좌표"]["영광영재도서관"] = "37.602983, 126.9070533"
loc_null_df["좌표"]["KB국민은행과 함께하는 나무작은도서관"] = "37.6538637, 127.0601291"
loc_null_df["좌표"]["산책마을 SH작은도서관"] = "37.6335037, 126.9338975"
#구글링으로 추가

# %%
#결측치 채우기 2. 위도와 경도(6)

for i in range(len(loc_null_df)):
    loc_null_df['위도'].values[i] = loc_null_df['좌표'].values[i].split(', ')[0]
    loc_null_df['경도'].values[i] = loc_null_df['좌표'].values[i].split(', ')[1]
    
# 받아온 좌표 값을 쪼개서 위도와 경도 열 채우기

# %%
loc_null_df.head()
#위도, 경도를 채운 데이터프레임
# Out:
#                                   시도명  시군구명  열람좌석수    자료수         위도  \
# 도서관명
# 사랑꿈터 작은 도서관                     서울특별시   은평구     20   4000  37.266946
# 용산 꿈나무도서관                       서울특별시   용산구    150  36597  37.538551
# 상림6 작은도서관                       서울특별시   은평구     20   8701  37.649089
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)        서울특별시   은평구     20   6024  37.644210
# 은평뉴타운5단지                        서울특별시   은평구     36   4001  37.636260
# 모퉁이작은도서관(은평뉴타운 상림마을 14단지 마을문고)  서울특별시   은평구     20   5283  37.644024
# 롯데캐슬문고                          서울특별시   은평구     32   6406  37.514248
# 상림책마루작은도서관                      서울특별시   은평구     35   5700  37.644024
# 우물골작은도서관                        서울특별시   은평구     20   5203   0.000000
# 큰꿈(을 키우는 작은)도서관                 서울특별시   은평구     55   8912  37.279719
# 래미안 푸른숲 도서관                     서울특별시   은평구     28   7000  37.281177
# 두드림 도서관                         서울특별시   은평구     30   6934  37.382991
# 종이책갈피 작은도서관                     서울특별시   은평구     16   4110  37.555803
# 푸른작은도서관                         서울특별시   은평구     25   6126   0.000000
# 솔빛도서관                           서울특별시   은평구     12   1628  37.771284
# 샘터작은도서관                         서울특별시   은평구     16   5282  37.246472
# 책뜰에도서관                          서울특별시   은평구     60   7000  37.643296
# 숲속 향기 작은도서관                     서울특별시   은평구     40   5920  37.635689
# 지혜누리작은도서관                       서울특별시   은평구     20   2556  37.339889
# 산책마을 SH작은도서관                    서울특별시   은평구     58   8599  37.633504
# 나누리작은도서관                        서울특별시   은평구     30   2500  37.632517
# 두근두근작은도서관 (마고정 3단지 도서관)         서울특별시   은평구     30   2400  37.632490
# 물푸레작은도서관                        서울특별시   은평구     35   5000  37.643658
# 새자람작은도서관                        서울특별시   은평구     10   1200  37.655541
# 포수마을 만화도서관                      서울특별시   은평구     30   2051  37.599007
# 백련산힐스 작은도서관                     서울특별시   은평구     22   3000  37.596918
# 영광영재도서관                         서울특별시   은평구     50   7058  37.602983
# 물빛마을작은도서관                       서울특별시   은평구     30   7903  35.105025
# 수색한숲도서관                         서울특별시   은평구     20   4007  37.586595
# 다섯콩작은도서관                        서울특별시   은평구     42  11661   0.000000
# 어린이도서관 동네북                      서울특별시   은평구     50  11899  37.576478
# 북한산 힐스테이트  1차 솔숲문고              서울특별시   은평구     40   7015  37.612612
# 책달샘숲속작은도서관                      서울특별시   금천구     14   2160  37.500588
# 자양한강도서관                         서울특별시   광진구    370  26139  37.529609
# KB국민은행과 함께하는 나무작은도서관            서울특별시  노원구　     20      0  37.653864
# 메아리작은도서관                        서울특별시  노원구　     14      0  37.653072
#
#                                         경도  도서관유형     건물면적  \
# 도서관명
# 사랑꿈터 작은 도서관                     126.990632  작은도서관    94.29
# 용산 꿈나무도서관                       126.965427  공공도서관  1104.00
# 상림6 작은도서관                       126.928076  작은도서관    94.29
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)        126.928874  작은도서관    94.29
# 은평뉴타운5단지                        126.935603  작은도서관   169.71
# 모퉁이작은도서관(은평뉴타운 상림마을 14단지 마을문고)  126.929028  작은도서관    94.29
# 롯데캐슬문고                          127.101273  작은도서관   150.86
# 상림책마루작은도서관                      126.929028  작은도서관   165.00
# 우물골작은도서관                          0.000000  작은도서관    94.29
# 큰꿈(을 키우는 작은)도서관                 126.851104  작은도서관   259.29
# 래미안 푸른숲 도서관                     127.066622  작은도서관   132.00
# 두드림 도서관                         127.122063  작은도서관   141.43
# 종이책갈피 작은도서관                     126.942155  작은도서관    75.43
# 푸른작은도서관                           0.000000  작은도서관   117.86
# 솔빛도서관                           126.778303  작은도서관    56.57
# 샘터작은도서관                         127.491401  작은도서관    75.43
# 책뜰에도서관                          126.922076  작은도서관   282.86
# 숲속 향기 작은도서관                     126.934379  작은도서관   188.57
# 지혜누리작은도서관                       127.922003  작은도서관    94.29
# 산책마을 SH작은도서관                    126.933898  작은도서관   273.43
# 나누리작은도서관                        126.925090  작은도서관   141.43
# 두근두근작은도서관 (마고정 3단지 도서관)         126.918633  작은도서관   141.43
# 물푸레작은도서관                        126.929737  작은도서관    78.00
# 새자람작은도서관                        126.948206  작은도서관    47.14
# 포수마을 만화도서관                      126.916503  작은도서관   141.43
# 백련산힐스 작은도서관                     126.923530  작은도서관   103.71
# 영광영재도서관                         126.907053  작은도서관   235.71
# 물빛마을작은도서관                       126.905014  작은도서관   141.43
# 수색한숲도서관                         126.900332  작은도서관    94.29
# 다섯콩작은도서관                          0.000000  작은도서관   198.00
# 어린이도서관 동네북                      126.967887  작은도서관   235.71
# 북한산 힐스테이트  1차 솔숲문고              126.936695  작은도서관   188.57
# 책달샘숲속작은도서관                      126.763679  작은도서관    61.03
# 자양한강도서관                         127.077972  공공도서관  1650.00
# KB국민은행과 함께하는 나무작은도서관            127.060129  작은도서관    94.29
# 메아리작은도서관                        127.057942  작은도서관    66.00
#
#                                                                    좌표
# 도서관명
# 사랑꿈터 작은 도서관                                   37.2669463, 126.9906323
# 용산 꿈나무도서관                                     37.5385513, 126.9654268
# 상림6 작은도서관                                     37.6490888, 126.9280755
# 은평뉴타운 상림마을  제7단지 문고(푸른꿈)                      37.6442098, 126.9288736
# 은평뉴타운5단지                                      37.6362597, 126.9356033
# 모퉁이작은도서관(은평뉴타운 상림마을 14단지 마을문고)                37.6440244, 126.9290277
# 롯데캐슬문고                                        37.5142479, 127.1012726
# 상림책마루작은도서관                                    37.6440244, 126.9290277
# 우물골작은도서관                                                         0, 0
# 큰꿈(을 키우는 작은)도서관                               37.2797194, 126.8511041
# 래미안 푸른숲 도서관                                   37.2811768, 127.0666219
# 두드림 도서관                                       37.3829909, 127.1220628
# 종이책갈피 작은도서관                                   37.5558027, 126.9421554
# 푸른작은도서관                                                          0, 0
# 솔빛도서관                                         37.7712841, 126.7783032
# 샘터작은도서관                                        37.246472, 127.4914009
# 책뜰에도서관                          37.64329638160066, 126.92207614232784
# 숲속 향기 작은도서관                                   37.6356894, 126.9343788
# 지혜누리작은도서관                                     37.3398891, 127.9220033
# 산책마을 SH작은도서관                                  37.6335037, 126.9338975
# 나누리작은도서관                                      37.6325169, 126.9250897
# 두근두근작은도서관 (마고정 3단지 도서관)                        37.6324903, 126.918633
# 물푸레작은도서관                                      37.6436577, 126.9297365
# 새자람작은도서관                                       37.6555415, 126.948206
# 포수마을 만화도서관                                    37.5990065, 126.9165033
# 백련산힐스 작은도서관                                   37.5969178, 126.9235298
# 영광영재도서관                                        37.602983, 126.9070533
# 물빛마을작은도서관                                      35.105025, 126.9050141
# 수색한숲도서관                                       37.5865949, 126.9003323
# 다섯콩작은도서관                                                         0, 0
# 어린이도서관 동네북                                      37.576478, 126.967887
# 북한산 힐스테이트  1차 솔숲문고                            37.6126118, 126.9366945
# 책달샘숲속작은도서관                                    37.5005875, 126.7636793
# 자양한강도서관                                       37.5296093, 127.0779724
# KB국민은행과 함께하는 나무작은도서관                          37.6538637, 127.0601291
# 메아리작은도서관                                       37.6530716, 127.057942

# %%
#데이터프레임 통합(1)

loc_null_df.reset_index(inplace=True)
#기존 df과 구조를 맞추기 위한 index reset

# %%
#데이터프레임 통합(2)

df_lib['위도'] = df_lib['위도'].fillna(0)
df_lib['경도'] = df_lib['경도'].fillna(0)
#기본 df의 위도, 경도 null값 조정
loc_exist_df = df_lib[ df_lib['위도'] != 0 ]
#null 값이 없는 df 생성
df_lib_filled = pd.concat([loc_exist_df, loc_null_df], axis=0, ignore_index=True)
#null 값이 없는 df와 null 값을 채운 df를 'df_lib_filled'로 통합

# %%
#데이터프레임 통합(3)

df_lib_filled['좌표'] = df_lib_filled['위도'].astype('str')+', '+df_lib_filled['경도'].astype('str')
#추후 작업을 위한 좌표열 생성

# %%
df_lib_filled.isnull().sum()
# Out:
# 건물면적     0
# 경도       0
# 도서관명     0
# 도서관유형    0
# 시군구명     0
# 시도명      0
# 열람좌석수    0
# 위도       0
# 자료수      0
# 좌표       0
# dtype: int64

# %%
df_lib_filled.head()
# Out:
#         건물면적          경도                     도서관명  도서관유형  시군구명    시도명  열람좌석수  \
# 0    1234.00  127.087557              중랑구립면목정보도서관  공공도서관   중랑구  서울특별시    227
# 1     977.80  127.103926                중랑숲어린이도서관  공공도서관   중랑구  서울특별시    303
# 2     133.00  127.074892                 중화어린이도서관  공공도서관   중랑구  서울특별시     30
# 3     970.78  127.110697                  양원숲속도서관  공공도서관   중랑구  서울특별시    252
# 4    1753.41  127.080932                  중랑상봉도서관  공공도서관   중랑구  서울특별시    268
# 5    3697.00  127.130477                 송파글마루도서관  공공도서관   송파구  서울특별시    414
# 6    1273.00  127.082428                 송파어린이도서관  공공도서관   송파구  서울특별시     60
# 7     886.00  127.146827                    거마도서관  공공도서관   송파구  서울특별시    244
# 8     177.00  127.118041                  소나무언덕1호  공공도서관   송파구  서울특별시     38
# 9     329.00  127.094217                  소나무언덕2호  공공도서관   송파구  서울특별시     72
# 10    343.00  127.156619                  소나무언덕3호  공공도서관   송파구  서울특별시     84
# 11    246.00  127.116836                  소나무언덕4호  공공도서관   송파구  서울특별시     45
# 12    510.00  127.078872               소나무언덕 잠실본동  공공도서관   송파구  서울특별시     63
# 13    595.00  127.102983                  송파어린이영어  공공도서관   송파구  서울특별시     60
# 14    265.00  127.103685                   돌마리도서관  공공도서관   송파구  서울특별시     55
# 15    914.00  127.143936                  송파위례도서관  공공도서관   송파구  서울특별시    140
# 16   5060.00  126.928267                  은평구립도서관  공공도서관   은평구  서울특별시    958
# 17   2110.00  126.907671                  증산정보도서관  공공도서관   은평구  서울특별시    511
# 18    999.00  126.919682                  응암정보도서관  공공도서관   은평구  서울특별시    250
# 19    311.70  126.928942                상림마을작은도서관  공공도서관   은평구  서울특별시     60
# 20   1997.00  126.933118                은평뉴타운 도서관  공공도서관   은평구  서울특별시    420
# 21   5106.00  127.086905                중랑구립정보도서관  공공도서관   중랑구  서울특별시    594
# 22   1724.86  126.967369                  사당솔밭도서관  공공도서관   동작구  서울특별시    280
# 23    525.00  126.950996                동작상도국주도서관  공공도서관   동작구  서울특별시    100
# 24    444.30  126.943434                 동작어린이도서관  공공도서관   동작구  서울특별시    130
# 25    391.30  126.925222                 대방어린이도서관  공공도서관   동작구  서울특별시     50
# 26    598.00  126.947440                    약수도서관  공공도서관   동작구  서울특별시     47
# 27    241.00  126.977553                  동작샘터도서관  작은도서관   동작구  서울특별시     50
# 28    183.00  126.973246                  다울작은도서관  작은도서관   동작구  서울특별시      8
# 29     36.00  126.940591               국사봉숲속작은도서관  작은도서관   동작구  서울특별시     10
# ..       ...         ...                      ...    ...   ...    ...    ...
# 502   150.86  127.101273                   롯데캐슬문고  작은도서관   은평구  서울특별시     32
# 503   165.00  126.929028               상림책마루작은도서관  작은도서관   은평구  서울특별시     35
# 504    94.29    0.000000                 우물골작은도서관  작은도서관   은평구  서울특별시     20
# 505   259.29  126.851104          큰꿈(을 키우는 작은)도서관  작은도서관   은평구  서울특별시     55
# 506   132.00  127.066622              래미안 푸른숲 도서관  작은도서관   은평구  서울특별시     28
# 507   141.43  127.122063                  두드림 도서관  작은도서관   은평구  서울특별시     30
# 508    75.43  126.942155              종이책갈피 작은도서관  작은도서관   은평구  서울특별시     16
# 509   117.86    0.000000                  푸른작은도서관  작은도서관   은평구  서울특별시     25
# 510    56.57  126.778303                    솔빛도서관  작은도서관   은평구  서울특별시     12
# 511    75.43  127.491401                  샘터작은도서관  작은도서관   은평구  서울특별시     16
# 512   282.86  126.922076                   책뜰에도서관  작은도서관   은평구  서울특별시     60
# 513   188.57  126.934379              숲속 향기 작은도서관  작은도서관   은평구  서울특별시     40
# 514    94.29  127.922003                지혜누리작은도서관  작은도서관   은평구  서울특별시     20
# 515   273.43  126.933898             산책마을 SH작은도서관  작은도서관   은평구  서울특별시     58
# 516   141.43  126.925090                 나누리작은도서관  작은도서관   은평구  서울특별시     30
# 517   141.43  126.918633  두근두근작은도서관 (마고정 3단지 도서관)  작은도서관   은평구  서울특별시     30
# 518    78.00  126.929737                 물푸레작은도서관  작은도서관   은평구  서울특별시     35
# 519    47.14  126.948206                 새자람작은도서관  작은도서관   은평구  서울특별시     10
# 520   141.43  126.916503               포수마을 만화도서관  작은도서관   은평구  서울특별시     30
# 521   103.71  126.923530              백련산힐스 작은도서관  작은도서관   은평구  서울특별시     22
# 522   235.71  126.907053                  영광영재도서관  작은도서관   은평구  서울특별시     50
# 523   141.43  126.905014                물빛마을작은도서관  작은도서관   은평구  서울특별시     30
# 524    94.29  126.900332                  수색한숲도서관  작은도서관   은평구  서울특별시     20
# 525   198.00    0.000000                 다섯콩작은도서관  작은도서관   은평구  서울특별시     42
# 526   235.71  126.967887               어린이도서관 동네북  작은도서관   은평구  서울특별시     50
# 527   188.57  126.936695       북한산 힐스테이트  1차 솔숲문고  작은도서관   은평구  서울특별시     40
# 528    61.03  126.763679               책달샘숲속작은도서관  작은도서관   금천구  서울특별시     14
# 529  1650.00  127.077972                  자양한강도서관  공공도서관   광진구  서울특별시    370
# 530    94.29  127.060129     KB국민은행과 함께하는 나무작은도서관  작은도서관  노원구　  서울특별시     20
# 531    66.00  127.057942                 메아리작은도서관  작은도서관  노원구　  서울특별시     14
#
#             위도     자료수                                      좌표
# 0    37.587356  112846       37.5873561521, 127.08755655959999
# 1    37.602634   50731                   37.602634, 127.103926
# 2    37.595004   23799      37.595003999999996, 127.0748924744
# 3    37.606825   29716                   37.606825, 127.110697
# 4    37.593127   26780               37.5931272353, 127.080932
# 5    37.480833   69064      37.480832692199996, 127.1304765731
# 6    37.512101   85296           37.5121012604, 127.0824284892
# 7    37.493545   44147      37.493545000000005, 127.1468273964
# 8    37.527417   18480           37.5274169166, 127.1180408616
# 9    37.507267   22286  37.507266666199996, 127.09421729809999
# 10   37.492325   24750           37.492325, 127.15661899999999
# 11   37.502207   17330                   37.502207, 127.116836
# 12   37.503101   23052       37.5031008494, 127.07887195709999
# 13   37.522393   19293       37.5223926038, 127.10298301430001
# 14   37.503565   16380           37.5035646147, 127.1036854792
# 15   37.481167   15645           37.4811666537, 127.1439359526
# 16   37.618974  259379         37.61897412, 126.92826740000001
# 17   37.582808   71917           37.5828079079, 126.9076711057
# 18   37.585967   72038           37.5859665629, 126.9196820594
# 19   37.644216   37261           37.6442159908, 126.9289423548
# 20   37.637230   54409           37.6372303968, 126.9331183475
# 21   37.615156  231096              37.6151557, 127.0869050507
# 22   37.484056   62011           37.484056, 126.96736899999999
# 23   37.506822   47410           37.5068219493, 126.9509960718
# 24   37.509204   50692        37.509204429, 126.94343400000001
# 25   37.503024   25363           37.5030242235, 126.9252221319
# 26   37.497851   34821         37.497851000000004, 126.9474396
# 27   37.488361   24667          37.488360899999996, 126.977553
# 28   37.478849    5368              37.4788487, 126.9732460032
# 29   37.495432    2826           37.4954320648, 126.9405908581
# ..         ...     ...                                     ...
# 502  37.514248    6406                 37.5142479, 127.1012726
# 503  37.644024    5700                 37.6440244, 126.9290277
# 504   0.000000    5203                                0.0, 0.0
# 505  37.279719    8912                 37.2797194, 126.8511041
# 506  37.281177    7000                 37.2811768, 127.0666219
# 507  37.382991    6934                 37.3829909, 127.1220628
# 508  37.555803    4110                 37.5558027, 126.9421554
# 509   0.000000    6126                                0.0, 0.0
# 510  37.771284    1628                 37.7712841, 126.7783032
# 511  37.246472    5282                  37.246472, 127.4914009
# 512  37.643296    7000   37.64329638160066, 126.92207614232784
# 513  37.635689    5920                 37.6356894, 126.9343788
# 514  37.339889    2556                 37.3398891, 127.9220033
# 515  37.633504    8599                 37.6335037, 126.9338975
# 516  37.632517    2500                 37.6325169, 126.9250897
# 517  37.632490    2400                  37.6324903, 126.918633
# 518  37.643658    5000                 37.6436577, 126.9297365
# 519  37.655541    1200                  37.6555415, 126.948206
# 520  37.599007    2051                 37.5990065, 126.9165033
# 521  37.596918    3000                 37.5969178, 126.9235298
# 522  37.602983    7058                  37.602983, 126.9070533
# 523  35.105025    7903                  35.105025, 126.9050141
# 524  37.586595    4007                 37.5865949, 126.9003323
# 525   0.000000   11661                                0.0, 0.0
# 526  37.576478   11899                   37.576478, 126.967887
# 527  37.612612    7015                 37.6126118, 126.9366945
# 528  37.500588    2160                 37.5005875, 126.7636793
# 529  37.529609   26139                 37.5296093, 127.0779724
# 530  37.653864       0                 37.6538637, 127.0601291
# 531  37.653072       0                  37.6530716, 127.057942
#
# [532 rows x 10 columns]

# %%
df_lib_filled.to_csv("꽉찬전국도서관표준데이터-20201223.csv", encoding='utf-8')
#파일로 저장
